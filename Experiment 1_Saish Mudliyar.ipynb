# %% [markdown]
# Experiment 1

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# Import First Dataset

# %%
df1=pd.read_csv('/content/sample_data/student_info.csv')
df1
# Out:
#    Student ID     Name  Age Grade
# 0         101    Alice   20     A
# 1         102      Bob   21     B
# 2         103  Charlie   19     A
# 3         104    David   22     C
# 4         105      Eve   20     B

# %% [markdown]
# Import Second Dataset

# %%
df2 = pd.read_csv('/content/sample_data/student_scores.csv')
df2
# Out:
#    Student ID  Math Score  English Score  Science Score
# 0         101          85             78             92
# 1         102          76             88             81
# 2         103          90             95             89
# 3         104          65             70             75
# 4         105          80             82             87

# %% [markdown]
# Merge Dataset

# %%
df3 = pd.concat([df1, df2], axis=1)
df3
# Out:
#    Student ID     Name  Age Grade  Student ID  Math Score  English Score  \
# 0         101    Alice   20     A         101          85             78
# 1         102      Bob   21     B         102          76             88
# 2         103  Charlie   19     A         103          90             95
# 3         104    David   22     C         104          65             70
# 4         105      Eve   20     B         105          80             82
#
#    Science Score
# 0             92
# 1             81
# 2             89
# 3             75
# 4             87
